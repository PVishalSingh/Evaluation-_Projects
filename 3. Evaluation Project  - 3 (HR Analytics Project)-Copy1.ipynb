# %% [markdown]
# # 3.Evaluation Project - (HR Analytics Project)

# %% [markdown]
# # <span style="color:red">By :- Punit Vishal Singh</span>

# %% [markdown]
# # <span style="color:blue">-----------------------------------------------------------------------------------------------------------------</span>

# %% [markdown]
# __--> HR Analytics__
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, __it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.__
#
# __--> Attrition in HR__
#
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.

# %% [markdown]
# # <span style="color:blue">-----------------------------> Attrition affecting Companies <-------------------------------------</span>

# %% [markdown]
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %% [markdown]
# # <span style="color:red">--------------------------------------> Problem Statement <------------------------------------------</span>

# %% [markdown]
# ## Understanding the Attritions in HR
#
# - Attrition is the departure of employees from the organization for any reason (voluntary or involuntary), including resignation, termination, death or retirement.

# %% [markdown]
# ### <span style="color:green">Import Packages</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### <span style="color:green">Loading The Dataset...............</span>

# %%
df=pd.read_csv("IBM_Hr_Analytics_Employee_Attrition_Performance.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# __NOTE:-__
#
# 1. AGE	--> consists Numerical Value
# 2. ATTRITION	--> consists Employee leaving the company (0=no, 1=yes)
# 3. BUSINESS TRAVEL	--> consists	(1=No Travel, 2=Travel Frequently, 3=Tavel Rarely)
# 4. DAILY RATE	--> consists Numerical Value - Salary Level
# 5. DEPARTMENT	--> consists	(1=HR, 2=R&D, 3=Sales)
# 6. DISTANCE FROM HOME	--> consists	Numerical Value - THE DISTANCE FROM WORK TO HOME
# 7. EDUCATION	--> consists	Numerical Value
# 8. EDUCATION FIELD	--> consists	(1=HR, 2=LIFE SCIENCES, 3=MARKETING, 4=MEDICAL SCIENCES, 5=OTHERS, 6= TEHCNICAL)
# 9. EMPLOYEE COUNT	--> consists	Numerical Value
# 10. EMPLOYEE NUMBER	--> consists	Numerical Value - EMPLOYEE ID
# 11. ENVIROMENT SATISFACTION	--> consists	Numerical Value - SATISFACTION WITH THE ENVIROMENT
# 12. GENDER	--> consists	(1=FEMALE, 2=MALE)
# 13. HOURLY RATE	--> consists	Numerical Value - HOURLY SALARY
# 14. JOB INVOLVEMENT	--> consists	Numerical Value - JOB INVOLVEMENT
# 15. JOB LEVEL	--> consists	Numerical Value - LEVEL OF JOB
# 16. JOB ROLE--> consists(1=HC REP, 2=HR, 3=LAB TECHNICIAN, 4=MANAGER, 5= MANAGING DIRECTOR, 6= REASEARCH DIRECTOR, 7= RESEARCH
# SCIENTIST, 8=SALES EXECUTIEVE, 9= SALES REPRESENTATIVE)
# 17. JOB SATISFACTION	--> consists	Numerical Value - SATISFACTION WITH THE JOB
# 18. MARITAL STATUS	--> consists	(1=DIVORCED, 2=MARRIED, 3=SINGLE)
# 19. MONTHLY INCOME	--> consists	Numerical Value - MONTHLY SALARY
# 20. MONTHY RATE	--> consists	Numerical Value - MONTHY RATE
# 21. NUMCOMPANIES WORKED	--> consists	Numerical Value - NO. OF COMPANIES WORKED AT
# 22. OVER 18	--> consists	(1=YES, 2=NO)
# 23. OVERTIME	--> consists	(1=NO, 2=YES)
# 24. PERCENT SALARY HIKE	--> consists	Numerical Value - PERCENTAGE INCREASE IN SALARY
# 25. PERFORMANCE RATING	--> consists	Numerical Value - ERFORMANCE RATING
# 26. RELATIONS SATISFACTION	--> consists	Numerical Value - RELATIONS SATISFACTION
# 27. STANDARD HOURS	--> consists	Numerical Value - STANDARD HOURS
# 28. STOCK OPTIONS LEVEL	--> consists	Numerical Value - STOCK OPTIONS
# 29. TOTAL WORKING YEARS	--> consists	Numerical Value - TOTAL YEARS WORKED
# 30. TRAINING TIMES LAST YEAR	--> consists	Numerical Value - HOURS SPENT TRAINING
# 31. WORK LIFE BALANCE	--> consists	Numerical Value - TIME SPENT BEWTWEEN WORK AND OUTSIDE
# 32. YEARS AT COMPANY	--> consists	Numerical Value - TOTAL NUMBER OF YEARS AT THE COMPNAY
# 33. YEARS IN CURRENT ROLE	--> consists	Numerical Value -YEARS IN CURRENT ROLE
# 34. YEARS SINCE LAST PROMOTION	--> consists	Numerical Value - LAST PROMOTION
# 35. YEARS WITH CURRENT MANAGER	--> consists	Numerical Value - YEARS SPENT WITH CURRENT MANAGER

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### <span style="color:green">To check the number of columns of object datatype</span>

# %%
obj = (df.dtypes == 'object')
print("Categorical variables:",len(list(obj[obj].index)))
# Out:
# Categorical variables: 9

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# # <span style="color:red">Exploratory Data Analysis (EDA)</span>

# %% [markdown]
# ### <span style="color:green">Checking Column Names</span>

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### <span style="color:green">-> Checking Null/Missing Values</span>

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### <span style="color:green">-> Checking Duplicate Values</span>

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# ### <span style="color:green">-> To Delete Duplicate Values and Keeping the First Value Only & Saving Dataset as df</span>

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# #### <span style="color:blue">Observation:-</span>
# - We don't have any duplicate value in the dataset

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %% [markdown]
# #### <span style="color:blue">Observation:-</span>
#
# * Here, we will have the range between -1 to +1 which will show the dependency between two columns.
# * It will show us three types of correlation between two columns.
#
#
# 1. __Positive Correlation__ --> When relationship of Variables are moving in the same direction --> Increase/Decrease in one variable is causing Increase/Decrease in other, respectively.
#
#
# 2. __Negative Correlation__ --> When relationship of Variables are moving in the opposite direction --> Increase/Decrease in one variable is causing Decrease/Increase in other, respectively.
#
#
# 3. __No/Zero Correlation__ --> When there is no relationship between the Variables --> Increase/Decrease in one variable is causing on impact on other.
#
#
# - All The columns are highly correlated with themselves --> Age with Age column = 1 means highly correlated.

# %% [markdown]
# ## <span style="color:red">Level Encoding</span>

# %% [markdown]
# ### <span style="color:green">To Encode Categorical Values of Attrition Column</span>

# %%
print(df['Attrition'].value_counts())
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df['Attrition'].value_counts()
df= df.replace({"Attrition":{"No":1, "Yes":1 }})
